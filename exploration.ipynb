# %%
import pandas as pd
import json
from src.scraper_functions import *
import re

# %%
df = pd.read_csv("data/google_fact_check/gfc.csv")

# %%
politifact = pd.read_csv('data/politifact/politifact_scrape_7t_03102022.csv')

# %%
# Out:
# array(['Instagram posts', 'Randy Feenstra', 'Facebook posts',
#        'Republican Party of Florida', 'Bloggers', 'Hillary Clinton',
#        'David Cicilline', 'Lamar Smith', 'Sacramento Bee Editorial Board',
#        'Anonymous GOP critics', 'EnergyCitizens.org', 'Joe Manchin',
#        'Tweets', 'Chain email', 'Viral image', 'Michelle Wolf',
#        'Brad Schneider', 'Bernie Sanders', "Martin O'Malley",
#        'Anna Kooiman', 'Dan Kaufman', 'Chris Murphy', 'Richard Durbin',
#        'Patrick Wales', 'Americans for Prosperity', 'Josh Mandel',
#        'Kris Jordan', 'Mark Hass', 'Stephen Kretzmann', 'Barack Obama',
#        'Glenn Beck', 'Tim Michels', 'Glenn Grothman', 'Ted Cruz',
#        'Carly Fiorina', 'Chris Taylor', 'Anita Perry', 'Dan Becker',
#        'NARAL Pro-Choice America', 'Rick Perry', 'Steve Oelrich',
#        'John Cornyn', 'John Boehner', 'Ron Johnson', 'Alex Berenson',
#        'Hal Turner Radio Show', 'Kathryn Moffett Bradford', 'Steve Deace',
#        'Joe Biden', 'Ted Budd', 'Steve Scalise', 'Tom Brady',
#        'John James', 'Tommy Tuberville', 'Chris Kapenga', 'Donald Trump',
#        'Jeff Shipley', 'Nate McMurray', 'Chris Larson', 'Charlie Kirk',
#        'Adrian Fontes', 'Kari Lake', 'Alex Lasry', 'Dan Patrick',
#        'Amanda Chase', 'Ben Wikler', 'Organizers for Bernie 2020',
#        'Club for Growth', 'Andrea Mitchell', 'Saundra McDowell',
#        'Kelda Helen Roys', 'Jon Husted', 'Phil Berger', 'Tammy Baldwin',
#        'Chris Sununu', 'Kamala Harris', 'Joaquin Castro', 'Georgia Voice',
#        'National Republican Senatorial Committee', 'Jonathan Karl',
#        'Kasim Reed', 'Occupy Democrats', 'George Will', 'Bee Moorhead',
#        'Robert Menendez', 'Marcia Fudge', "Workers' Voice",
#        'Scott Walker', 'Debra Medina', 'Kim Simac', 'Ellen Freidin',
#        'Steven Schale', 'Michael Steele',
#        'Citizens for Lower Taxes and a Stronger Economy', 'John McCain',
#        'Chris Dodd', 'Omar Rachid', 'Rob Wittman', 'Ben Carson',
#        'Mark Pocan', 'Jonathan Turley', 'Julie Pace', 'Trey Gowdy',
#        'Tom Cotton', 'YouTube videos', 'VoteVets'], dtype=object)

# %%
def read_topics(path_to_file):
    topics = []
    with open(path_to_file, "r") as lines:
        for line in lines.readlines():
            line = line.strip()
            line = re.sub(" ", "-", line)
            topics.append(line.lower())
    return topics


topics = read_topics("src/topics.txt")

# %%
topics
# Out:
# ['ad-watch',
#  'afghanistan',
#  'after-the-fact',
#  'agriculture',
#  'alcohol',
#  'animals',
#  'ask-politifact',
#  'autism',
#  'bankruptcy',
#  'baseball',
#  'bipartisanship',
#  'border-security',
#  'bush-administration',
#  'campaign-finance',
#  'candidate-biography',
#  'cap-and-trade',
#  'census',
#  'children',
#  'china',
#  'city-budget',
#  'city-government',
#  'civil-rights',
#  'climate-change',
#  'congress',
#  'constitutional-amendments',
#  'consumer-safety',
#  'coronavirus',
#  'corporations',
#  'corrections-and-updates',
#  'county-budget',
#  'county-government',
#  'crime',
#  'criminal-justice',
#  'death-penalty',
#  'debates',
#  'debt',
#  'deficit',
#  'disability',
#  'drugs',
#  'ebola',
#  'economy',
#  'education',
#  'elections',
#  'energy',
#  'environment',
#  'ethics',
#  'facebook-fact-checks',
#  'fake-news',
#  'families',
#  'federal-budget',
#  'financial-regulation',
#  'fires',
#  'florida-amendments',
#  'food',
#  'food-safety',
#  'foreign-policy',
#  'gambling',
#  'gas-prices',
#  'government-regulation',
#  'guns',
#  'health-care',
#  'health-check',
#  'history',
#  'homeland-security',
#  'homeless',
#  'housing',
#  'human-rights',
#  'immigration',
#  'impeachment',
#  'income',
#  'infrastructure',
#  'iran',
#  'iraq',
#  'islam',
#  'israel',
#  'jan.-6',
#  'jobs',
#  'kagan-nomination',
#  'katrina',
#  'labor',
#  'legal-issues',
#  'lgbtq',
#  'lottery',
#  'kagan-nomination',
#  'katrina',
#  'labor',
#  'legal-issues',
#  'lgbtq',
#  'lottery',
#  'marijuana',
#  'marriage',
#  'medicaid',
#  'medicare',
#  'message-machine-2010',
#  'message-machine-2012',
#  'message-machine-2014',
#  'military',
#  'natural-disasters',
#  'negative-campaigning',
#  'new-hampshire-2012',
#  'nuclear',
#  'obama-birth-certificate',
#  'occupy-wall-street',
#  'oil-spill',
#  'party-support',
#  'patriotism',
#  'pensions',
#  'politifact-en-español',
#  "politifact's-top-promises",
#  'polls-and-public-opinion',
#  'pop-culture',
#  'population',
#  'poverty',
#  'privacy-issues',
#  'public-health',
#  'public-safety',
#  'public-service',
#  'pundits',
#  'race-and-ethnicity',
#  'recreation',
#  'redistricting',
#  'regulation',
#  'religion',
#  'retirement',
#  'russia',
#  'science',
#  'second-term-promise',
#  'sexuality',
#  'small-business',
#  'social-security',
#  'sotomayor-nomination',
#  'space',
#  'sports',
#  'state-budget',
#  'states',
#  'stimulus',
#  'supreme-court',
#  'tampa-bay-10-news',
#  'taxes',
#  'technology',
#  'terrorism',
#  "the-2018-california-governor's-race",
#  'this-week---abc-news',
#  'tourism',
#  'trade',
#  'transparency',
#  'transportation',
#  'ukraine',
#  'unions',
#  'urban',
#  'veterans',
#  'voter-id-laws',
#  'voting-record',
#  'water',
#  'wealth',
#  'weather',
#  'welfare',
#  'women',
#  'workers']

# %%
import requests

for topic in topics: 
    base_url = 'https://www.politifact.com/factchecks/list/?page={page_number}&category={topic}'.format(page_number=1, topic=topic)
    print(topics.index(topic))
    
    req = requests.get(base_url)
    
    print(req.status_code)
# Out:
# 0
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 89
# 200
# 90
# 200
# 91
# 200
# 92
# 200
# 93
# 200
# 94
# 200
# 95
# 200
# 96
# 200
# 97
# 200
# 98
# 200
# 99
# 200
# 100
# 200
# 101
# 200
# 102
# 200
# 103
# 200
# 104
# 200
# 105
# 200
# 106
# 200
# 107
# 200
# 108
# 200
# 109
# 200
# 110
# 200
# 111
# 200
# 112
# 200
# 113
# 200
# 114
# 200
# 115
# 200
# 116
# 200
# 117
# 200
# 118
# 200
# 119
# 200
# 120
# 200
# 121
# 200
# 122
# 200
# 123
# 200
# 124
# 200
# 125
# 200
# 126
# 200
# 127
# 200
# 128
# 200
# 129
# 200
# 130
# 200
# 131
# 200
# 132
# 200
# 133
# 200
# 134
# 200
# 135
# 200
# 136
# 200
# 137
# 200
# 138
# 200
# 139
# 200
# 140
# 200
# 141
# 200
# 142
# 200
# 143
# 200
# 144
# 200
# 145
# 200
# 146
# 200
# 147
# 200
# 148
# 200
# 149
# 200
# 150
# 200
# 151
# 200
# 152
# 200
# 153
# 200
# 154
# 200
# 155
# 200
# 156
# 200
# 157
# 200
# 158
# 200

# %%
len(topics)
# Out:
# 159
